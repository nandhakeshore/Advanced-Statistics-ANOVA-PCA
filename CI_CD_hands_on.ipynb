# %% [markdown]
# <a href="https://colab.research.google.com/github/nandhakeshore/Advanced-Statistics-ANOVA-PCA/blob/main/CI_CD_hands_on.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

# Create dummy data
data = pd.DataFrame({
    "x": [1, 2, 3, 4],
    "y": [0, 1, 0, 1]
})

# Train model
model = LogisticRegression()
model.fit(data[["x"]], data["y"])

print("Model trained successfully")
# Out:
# Model trained successfully
